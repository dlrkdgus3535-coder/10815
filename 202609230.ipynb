# %% [markdown]
# <a href="https://colab.research.google.com/github/dlrkdgus3535-coder/10815/blob/main/202609230.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = set
s1 = {3,2,3}
s2 = {9,1,3}
print(s1)
print(s2)
# Out:
# {2, 3}
# {9, 3, 1}

# %%
s1.add(10)
print(s1)
s1.update([2,1])
print(s1)
s1.discard(10)
print(s1)
#s1.remove(3)
print(s1)
print(s1&s2)
print(s1.union(s2))
print(s1-s2)
s1.clear
print(s1)
# Out:
# {10, 1, 2}
# {10, 1, 2}
# {1, 2}
# {1, 2}
# {1}
# {1, 2, 3, 9}
# {2}
# {1, 2}

# %%
a=['우유','빵','버터','빵','치즈','과자','우유']
b=['빵','과일','야채','버터','우유','커피']
print (set(a))
aprint(set(a)&set(b))
# Out:
# {'치즈', '우유', '과자', '버터', '빵'}
# {'우유', '버터', '빵'}

# %%
a= input('첫 번쨰 영어 문장을 입력하세요:')
b= input('두 번쨰 영어 문장을 입력하세요:')
c= input('세 번쨰 영어 문장을 입력하세요:')
text = a+''+b+ ''+c
text = text.replace(',','').replace(',','')
text = text.lower()
words = text.split()
unique_words = set(words)
sorted_unique_words = sorted(unique_words)
# Out:
# 첫 번쨰 영어 문장을 입력하세요:rhghs
# 두 번쨰 영어 문장을 입력하세요:aga
# 세 번쨰 영어 문장을 입력하세요:afgsdh

# %%
import random
mem = ['김민준', '이서준', '박도윤','최시우','정예준','이강현']
winners_cnt = int(input('뽑을 당첨자 수를 입력하세요:'))
winners = random.sample(mem, winners_cnt)
winners.sort()
print(winners)
# Out:
# 뽑을 당첨자 수를 입력하세요:2
# ['이서준', '최시우']
