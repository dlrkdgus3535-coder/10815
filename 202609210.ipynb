# %% [markdown]
# <a href="https://colab.research.google.com/github/dlrkdgus3535-coder/10815/blob/main/202609210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= {}
b= {88: 'seoul',24: 'paris','num':[10,20]}
c= {'name': 'kim', 'name': 'lee'}
print(a, type(a))
print(len(b))
print(b[88])
print(c['name'])
# Out:
# {} <class 'dict'>
# 3
# seoul
# lee

# %%
a={88: 'londan' , 20: 'tokyo'}
a[88] = 'seoul'
a[24] = 'paris'
del a[20]
a.update({24: 'busan'})
a.update({30: 'suwon'})
print(a)
# Out:
# {88: 'seoul', 24: 'busan', 30: 'suwon'}

# %%
dic={'grape': '포도','apple': '사과'}
print(dic)
print(sorted(dic))
print(sorted(dic, reverse=True))
print(sorted(dic.items()))
print('apple'in dic)
print(dic.items())
print(dic.get('apple','gg'))
# Out:
# {'grape': '포도', 'apple': '사과'}
# ['apple', 'grape']
# ['grape', 'apple']
# [('apple', '사과'), ('grape', '포도')]
# True
# dict_items([('grape', '포도'), ('apple', '사과')])
# 사과

# %%
print(dic.keys())
print(dic.values())
print(sorted(dic.values()))
print(dic.items())
p=dic.pop('apple')
print(p)
print(dic)
print(dic.get('grape'))
print(dic.get('apple'))
print(dic.get('apple',"없음"))
dic.clear()
print(dic)
# Out:
# dict_keys(['grape', 'apple'])
# dict_values(['포도', '사과'])
# ['사과', '포도']
# dict_items([('grape', '포도'), ('apple', '사과')])
# 사과
# {'grape': '포도'}
# 포도
# None
# 없음
# {}

# %%
a={'burger':5000,'pizza:8000,'pasta':7000}
menu['pizza']=8500
mennu['chicken']=10000
del menu['pasta']
print(menu)
print('가격 역순 정렬:, sorted(menu.values(), reserve= True)')
# Out:
#   File "/tmp/ipykernel_829/1171223419.py", line 1
#     a={'burger':5000,'pizza:8000,'pasta' :7000}
#                                        ^
# SyntaxError: unterminated string literal (detected at line 1)
