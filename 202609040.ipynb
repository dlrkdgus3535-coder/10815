# %% [markdown]
# <a href="https://colab.research.google.com/github/dlrkdgus3535-coder/10815/blob/main/202609040.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input('이름:')
b=input('나이:')
print(a, '님 안녕하새요?')
print(20-int(b),'년 후면 20살이시네요!')
# Out:
# 이름:이강현
# 나이:17
# 이강현 님 안녕하새요?
# 3 년 후면 20살이시네요!

# %%
print(7/3)
print(7//3)
print(7%3)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
sec=int(input('시간을 초 단위로 입력하세요:'))
minutes = sec//60
seconds = sec %60
print(f'{minutes}분 {seconds}초')
# Out:
# 시간을 초 단위로 입력하세요:12
# 0분 12초

# %%
print(' ###########################')
print('[한양과학기술고등학교]')

input('이름:')
input('학번:')
input('소속:')


print('[위 사람은 본 학교의 학생임을 증명함]')

print('###############################')
# Out:
#  ###########################
# [한양과학기술고등학교]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_938/3413688819.py in <cell line: 0>()
#       1 print(' ###########################')
#       2 print('[한양과학기술고등학교]')
# ----> 3 input('이름:')
#       4 input('학번:')
#       5 input('소속:')
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
